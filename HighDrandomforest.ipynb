# %% [markdown]
# <a href="https://colab.research.google.com/github/michiru123/HighD-dataset/blob/master/HighDrandomforest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Random Forest Structures using network
# Random Forest is a set of multiple decision tree, with the random combination between meaningful features. We can transform this model into a network to investigate  simultanously the contribution of each feature and their correlations. In the network, features is nodes, one edge is formed between 2 features when they both join in a decision tree.
#
# In the optimization stage, Random Forest model just keep features that hold most important roles and these fatures scattered within decision trees. The higher frequency of a feature appears in almost decision trees, the more important of that feature.
#
# Although the importance of a feature can be tested by variable importance, this method could not indicate the correlation between important features: a group of random features will correlate when they are in same decision tree structures. Beside joining randomly, a feature can combine with different features to create the rule for the decision tree, and a feature group appears in multiple trees mean they are important.

# %%
from __future__ import print_function
import warnings
warnings.filterwarnings('ignore')

from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split 

import numpy as np
import pandas as pd

from numpy import random as nprand
import random
nprand.seed(100)
random.seed(100)

import networkx as nx

import seaborn as sns
from matplotlib import pyplot as plt

plt.rcParams.update({
    'figure.figsize': (15, 15),
    'axes.spines.right': False,
    'axes.spines.left': False,
    'axes.spines.top': False,
    'axes.spines.bottom': False})

# %% [markdown]
# ###HighD Dataset
# We will use track 45 of HighD Dataset (2000 vehicles) for feature selections among 32 features.

# %%
# %cd /content/drive/My Drive/1 phd2020/HighD Dataset/data
# !ls
# Out:
# /content/drive/My Drive/1 phd2020/HighD Dataset/data
#  01_highway.png         21_tracks.csv	       42_highway.png
#  01_recordingMeta.csv   21_tracksMeta.csv      42_recordingMeta.csv
#  01_tracks.csv	        22_highway.png	       42_tracks.csv
#  01_tracksMeta.csv      22_recordingMeta.csv   42_tracksMeta.csv
#  02_highway.png         22_tracks.csv	       43_highway.png
#  02_recordingMeta.csv   22_tracksMeta.csv      43_recordingMeta.csv
#  02_tracks.csv	        23_highway.png	       43_tracks.csv
#  02_tracksMeta.csv      23_recordingMeta.csv   43_tracksMeta.csv
#  03_highway.png         23_tracks.csv	       44_highway.png
#  03_recordingMeta.csv   23_tracksMeta.csv      44_recordingMeta.csv
#  03_tracks.csv	        24_highway.png	       44_tracks.csv
#  03_tracksMeta.csv      24_recordingMeta.csv   44_tracksMeta.csv
#  04_highway.png         24_tracks.csv	       45_highway.png
#  04_recordingMeta.csv   24_tracksMeta.csv      45_recordingMeta.csv
#  04_tracks.csv	        25_highway.png	       45_tracks.csv
#  04_tracksMeta.csv      25_recordingMeta.csv   45_tracksMeta.csv
#  05_highway.png         25_tracks.csv	       45_tracksN.csv
#  05_recordingMeta.csv   25_tracksMeta.csv      46_highway.png
#  05_tracks.csv	        26_highway.png	       46_recordingMeta.csv
#  05_tracksMeta.csv      26_recordingMeta.csv   46_tracks.csv
#  06_highway.png         26_tracks.csv	       46_tracksMeta.csv
#  06_recordingMeta.csv   26_tracksMeta.csv      47_highway.png
#  06_tracks.csv	        27_highway.png	       47_recordingMeta.csv
#  06_tracksMeta.csv      27_recordingMeta.csv   47_tracks.csv
#  07_highway.png         27_tracks.csv	       47_tracksMeta.csv
#  07_recordingMeta.csv   27_tracksMeta.csv      48_highway.png
#  07_tracks.csv	        28_highway.png	       48_recordingMeta.csv
#  07_tracksMeta.csv      28_recordingMeta.csv   48_tracks.csv
#  08_highway.png         28_tracks.csv	       48_tracksMeta.csv
#  08_recordingMeta.csv   28_tracksMeta.csv      49_highway.png
#  08_tracks.csv	        29_highway.png	       49_recordingMeta.csv
#  21_highway.png         41_tracks.csv	       Track45_processed.gsheet
#  21_recordingMeta.csv   41_tracksMeta.csv

# %%
df = pd.read_csv('Track45_processed.csv')
df
# Out:
#       Unnamed: 0    id  ...  mean_laneId  numLaneChanges
# 0              0     1  ...          6.0               0
# 1              1     2  ...          4.0               0
# 2              2     3  ...          8.0               0
# 3              3     4  ...          7.0               0
# 4              4     5  ...          8.0               0
# ...          ...   ...  ...          ...             ...
# 2444        2444  2445  ...          4.0               0
# 2445        2445  2446  ...          2.0               0
# 2446        2446  2447  ...          7.0               0
# 2447        2447  2448  ...          6.0               0
# 2448        2448  2449  ...          4.0               0
#
# [2449 rows x 33 columns]

# %%
Xdf = df.drop('numLaneChanges', 1)
Xdf['class'] = pd.get_dummies(Xdf['class']) #1:Car 0:Truck
Xdf.head()
# Out:
#    Unnamed: 0  id  ...  max_precedingXVelocity  mean_laneId
# 0           0   1  ...                     0.0          6.0
# 1           1   2  ...                     0.0          4.0
# 2           2   3  ...                     0.0          8.0
# 3           3   4  ...                     0.0          7.0
# 4           4   5  ...                    26.9          8.0
#
# [5 rows x 32 columns]

# %%
y = df['numLaneChanges']
features = np.array(Xdf.columns)

# %% [markdown]
# Then we create a RandomForest classifier with 500 decision trees in X

# %%
clf = RandomForestClassifier(max_depth=5, random_state=0, n_estimators=500)
clf.fit(Xdf, y)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=5, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=500,
#                        n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                        warm_start=False)

# %% [markdown]
# These decision tree are saved as estimators_ of model object:

# %%
clf.estimators_[0:3]
# Out:
# [DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                         max_depth=5, max_features='auto', max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort='deprecated',
#                         random_state=209652396, splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                         max_depth=5, max_features='auto', max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort='deprecated',
#                         random_state=398764591, splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                         max_depth=5, max_features='auto', max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort='deprecated',
#                         random_state=924231285, splitter='best')]

# %% [markdown]
# each decision tree has data of most important features, and stored in featureimportance.

# %%
clf.estimators_[99].feature_importances_
# Out:
# array([0.00207494, 0.        , 0.        , 0.0037153 , 0.        ,
#        0.00844254, 0.        , 0.        , 0.        , 0.        ,
#        0.        , 0.01298652, 0.00206756, 0.        , 0.        ,
#        0.        , 0.09870714, 0.        , 0.108125  , 0.        ,
#        0.00395744, 0.        , 0.11131424, 0.56371084, 0.01208531,
#        0.05266602, 0.00204727, 0.00879431, 0.        , 0.00284443,
#        0.        , 0.00646113])

# %% [markdown]
# We can drop all features with importance score = 0.0, since it doesnt impact on rules of decision tree, the decision tree number 99 has 16 important features.

# %%
sum(clf.estimators_[99].feature_importances_ > 0)
# Out:
# 16

# %% [markdown]
# Then we write a function to transfer info of features importance into a network, the function will receive data as random forest model, with list of features in X, and feature importance threshold as 0.15...
#
# Network was create as a Graph, each time 1 feature appear in 1 decition tree, and have feature importance score higher than the threshold, it will be stored in the network as a node, the number of feature appearance in different decision trees will be culmulated to make "count" feature, the value of feature importance also added up to create feature " score", then feature "avg_vimp" is the average of feature importance = sum of score / sum count. When 2 features are selected in 1 tree, 1 edge between 2 nodes will be created, the number of pairing of these nodes will be written in feature "count" as the weight of edge.

# %%
   def random_forest_to_network(rf_mod, features, thres = 0.1):
    
    G = nx.Graph()
    trees = rf_mod.estimators_
    
    for tree in trees:
        vimp_scores = tree.feature_importances_
        vimps = features[vimp_scores > thres]
        scores = vimp_scores[vimp_scores > thres]
        
        for v,s in zip(vimps,scores):
            try:
                G.nodes[v]['count'] += 1
                G.nodes[v]['score'] += s
            except KeyError:
                G.add_node(v)
                G.nodes[v]['count'] = 1
                G.nodes[v]['score'] = s
            for w in vimps:
                try:
                    G.edges[v, w]['count'] += 1
                except KeyError:
                    G.add_edge(v, w, count=1)
    
    for n,d in G.nodes(data = True):
        G.nodes[n]['avg_vimp'] = d['score']/d['count']
    
    return G

# %% [markdown]
# We apply the function for RF model and X

# %%
features = np.array(Xdf.columns)

G = random_forest_to_network(clf, features, thres = 0.15)

# %% [markdown]
# There are 8 features (nodes) written in the network.

# %%
len(G.nodes)
# Out:
# 11

# %% [markdown]
# and 29 pairs

# %%
len(G.edges)
# Out:
# 48

# %% [markdown]
# features of nodes:

# %%
G.nodes(data=True)
# Out:
# NodeDataView({'max_yVelocity': {'count': 191, 'score': 56.00489265808484, 'avg_vimp': 0.29321933328840233}, 'mean_yVelocity': {'count': 300, 'score': 103.48508017251045, 'avg_vimp': 0.3449502672417015}, 'mean_yAcceleration': {'count': 59, 'score': 8.177773820685417, 'avg_vimp': 0.13860633594382063}, 'min_yVelocity': {'count': 179, 'score': 54.30568019976236, 'avg_vimp': 0.3033836882668288}, 'max_yAcceleration': {'count': 233, 'score': 92.02359368366551, 'avg_vimp': 0.3949510458526417}, 'min_yAcceleration': {'count': 207, 'score': 82.88740921707854, 'avg_vimp': 0.4004222667491717}, 'minTHW': {'count': 6, 'score': 0.6337144863049866, 'avg_vimp': 0.1056190810508311}, 'mean_laneId': {'count': 8, 'score': 2.2096800501089318, 'avg_vimp': 0.27621000626361647}, 'min_frontSightDistance': {'count': 2, 'score': 0.223569976697522, 'avg_vimp': 0.111784988348761}, 'min_precedingXVelocity': {'count': 2, 'score': 0.21896461278018786, 'avg_vimp': 0.10948230639009393}, 'minDHW': {'count': 2, 'score': 0.27356150940588764, 'avg_vimp': 0.13678075470294382}})

# %% [markdown]
# features of edges

# %%
G.edges(data =True)
# Out:
# EdgeDataView([('max_yVelocity', 'max_yVelocity', {'count': 191}), ('max_yVelocity', 'mean_yVelocity', {'count': 206}), ('max_yVelocity', 'mean_yAcceleration', {'count': 34}), ('max_yVelocity', 'min_yVelocity', {'count': 134}), ('max_yVelocity', 'max_yAcceleration', {'count': 142}), ('max_yVelocity', 'min_yAcceleration', {'count': 124}), ('max_yVelocity', 'minTHW', {'count': 6}), ('max_yVelocity', 'mean_laneId', {'count': 2}), ('max_yVelocity', 'min_frontSightDistance', {'count': 2}), ('mean_yVelocity', 'mean_yVelocity', {'count': 300}), ('mean_yVelocity', 'mean_yAcceleration', {'count': 46}), ('mean_yVelocity', 'min_yVelocity', {'count': 168}), ('mean_yVelocity', 'max_yAcceleration', {'count': 240}), ('mean_yVelocity', 'min_yAcceleration', {'count': 216}), ('mean_yVelocity', 'minTHW', {'count': 6}), ('mean_yVelocity', 'mean_laneId', {'count': 4}), ('mean_yVelocity', 'min_precedingXVelocity', {'count': 4}), ('mean_yVelocity', 'minDHW', {'count': 2}), ('mean_yAcceleration', 'mean_yAcceleration', {'count': 59}), ('mean_yAcceleration', 'max_yAcceleration', {'count': 52}), ('mean_yAcceleration', 'min_yAcceleration', {'count': 56}), ('mean_yAcceleration', 'min_yVelocity', {'count': 28}), ('mean_yAcceleration', 'mean_laneId', {'count': 2}), ('mean_yAcceleration', 'minTHW', {'count': 4}), ('mean_yAcceleration', 'min_frontSightDistance', {'count': 2}), ('min_yVelocity', 'min_yVelocity', {'count': 179}), ('min_yVelocity', 'max_yAcceleration', {'count': 146}), ('min_yVelocity', 'min_yAcceleration', {'count': 122}), ('min_yVelocity', 'minTHW', {'count': 4}), ('min_yVelocity', 'mean_laneId', {'count': 6}), ('min_yVelocity', 'min_frontSightDistance', {'count': 2}), ('min_yVelocity', 'min_precedingXVelocity', {'count': 2}), ('max_yAcceleration', 'max_yAcceleration', {'count': 233}), ('max_yAcceleration', 'min_yAcceleration', {'count': 128}), ('max_yAcceleration', 'minTHW', {'count': 10}), ('max_yAcceleration', 'mean_laneId', {'count': 6}), ('max_yAcceleration', 'min_precedingXVelocity', {'count': 4}), ('max_yAcceleration', 'min_frontSightDistance', {'count': 2}), ('min_yAcceleration', 'min_yAcceleration', {'count': 207}), ('min_yAcceleration', 'min_frontSightDistance', {'count': 2}), ('min_yAcceleration', 'mean_laneId', {'count': 8}), ('min_yAcceleration', 'min_precedingXVelocity', {'count': 2}), ('min_yAcceleration', 'minDHW', {'count': 4}), ('minTHW', 'minTHW', {'count': 6}), ('mean_laneId', 'mean_laneId', {'count': 8}), ('min_frontSightDistance', 'min_frontSightDistance', {'count': 2}), ('min_precedingXVelocity', 'min_precedingXVelocity', {'count': 2}), ('minDHW', 'minDHW', {'count': 2})])

# %%
node_sizes = [5000*d['avg_vimp'] for n,d in G.nodes(data = True)]
weights = [np.log2(d['count']) for s, t, d in G.edges(data=True)]

pos=nx.spring_layout(G, k = 0.6)

nx.draw_networkx_nodes(G, pos, alpha=1.0, node_size = node_sizes , node_color = 'red')
nx.draw_networkx_labels(G, pos, font_size = 12, font_color = 'black')
nx.draw_networkx_edges(G, pos, edge_color="red", width = weights, alpha=0.5)

# %%
node_sizes = [5000*d['avg_vimp'] for n,d in G.nodes(data = True)]
weights = [np.log2(d['count']) for s, t, d in G.edges(data=True)]

pos=nx.spring_layout(G, k=0.6)

nx.draw_networkx_nodes(G, pos, alpha=1.0, node_size = node_sizes , node_color = '#fca903')
nx.draw_networkx_labels(G, pos, font_size = 12, font_color = 'black')
nx.draw_networkx_edges(G, pos, edge_color='#fc5a03',width = weights, alpha=0.6)

# %%
df
# Out:
#       Unnamed: 0    id  ...  mean_laneId  numLaneChanges
# 0              0     1  ...          6.0               0
# 1              1     2  ...          4.0               0
# 2              2     3  ...          8.0               0
# 3              3     4  ...          7.0               0
# 4              4     5  ...          8.0               0
# ...          ...   ...  ...          ...             ...
# 2444        2444  2445  ...          4.0               0
# 2445        2445  2446  ...          2.0               0
# 2446        2446  2447  ...          7.0               0
# 2447        2447  2448  ...          6.0               0
# 2448        2448  2449  ...          4.0               0
#
# [2449 rows x 33 columns]

# %%
df['class'] = pd.get_dummies(Xdf['class']) #1:Car 0:Truck
df.head()
# Out:
#    Unnamed: 0  id  width  ...  max_precedingXVelocity  mean_laneId  numLaneChanges
# 0           0   1   4.24  ...                     0.0          6.0               0
# 1           1   2   4.14  ...                     0.0          4.0               0
# 2           2   3  17.99  ...                     0.0          8.0               0
# 3           3   4  17.79  ...                     0.0          7.0               0
# 4           4   5   4.85  ...                    26.9          8.0               0
#
# [5 rows x 33 columns]
